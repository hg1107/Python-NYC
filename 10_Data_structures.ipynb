# %%
"""
Data Structures are ways to store data in a computer.
1. Lists
2. Tuples
3. Sets
4. Dictionaries


Linked list
Queue
Tree
Hash Map
"""
# Out:
# '\nData Structures are ways to store data in a computer.\n1. Lists\n2. Tuples\n3. Sets\n4. Dictionaries\n\n\nLinked list\nQueue\nTree\nHash Map\n'
