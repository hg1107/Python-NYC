# %% [raw]
# Does not exist in python, but can be achieved using libraries
# Used to simplifying complex systems by focusing on essential features and hiding unnecessary details
# Used to define a common interface for different subclasses

# %%
from abc import ABC, abstractmethod

class Enforce(ABC):
    @abstractmethod
    def engine_start():
        pass

class Bike(Enforce):
    pass

class Car(Enforce):
    pass

class Truck:
    pass

obj1 = Bike()
obj2 = Car()
obj3 = Truck()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 17
#      14 class Truck:
#      15     pass
# ---> 17 obj1 = Bike()
#      18 obj2 = Car()
#      19 obj3 = Truck()
#
# TypeError: Can't instantiate abstract class Bike without an implementation for abstract method 'engine_start'

# %%
from abc import ABC, abstractmethod

class Enforce(ABC):
    @abstractmethod
    def engine_start():
        pass

class Bike(Enforce):
    def engine_start():
            pass

class Car(Enforce):
    def engine_start():
            pass

class Truck:
    pass

obj1 = Bike()
obj2 = Car()
obj3 = Truck()

# %% [raw]
# If a parent class contains an abstract method, then we need to implement that method in every child classes
