# %%
a = int(input("Enter First number: "))
b = int(input("Enter Second number: "))

try:
    print(a/b)
except Exception as er:
    print("Exception occured: ", er)
# Out:
# Exception occured:  division by zero

# %%
a = int(input("Enter First number: "))
b = int(input("Enter Second number: "))

try:
    print(a/b)
except Exception as er:
    print("Exception occured: ", er)
else:
    print("No error occured") # Run only if no exception
# Out:
# 4.0
# No error occured

# %%
a = int(input("Enter First number: "))
b = int(input("Enter Second number: "))

try:
    print(a/b)
except Exception as er:
    print("Exception occured: ", er)
finally:
    print("Runs irrespective of error")
# Out:
# Exception occured:  division by zero
# Runs irrespective of error

# %%
# Raise: Manually throw own exception:

age = int(input("Enter your age: "))

if age < 18:
    raise ValueError("You are not eligible [Custom message]")

print("You are eligible")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 6
#       3 age = int(input("Enter your age: "))
#       5 if age < 18:
# ----> 6     raise ValueError("You are not eligible [Custom message]")
#       8 print("You are eligible")
#
# ValueError: You are not eligible [Custom message]
