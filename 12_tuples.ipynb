# %% [raw]
# They are just like list, but immutable.
# use for data that should stay constant
# like days of the week, coordinates, or config values

# %%
days = ("Mon", "Tue", "Wed")
print(days)
print(days[0])
# Out:
# ('Mon', 'Tue', 'Wed')
# Mon

# %%
lst = [1, 2, 3, 4, 5]
tup = tuple(lst)

print(tup)
print(type(tup))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %% [markdown]
# ## Methods

# %%
# Index

days.index("Tue")
# Out:
# 1

# %%
# Count --> Return how many times any element appears
count = (1, 1, 1, 2, 3, 3, 1, 1)
count.count(1)
# Out:
# 5

# %%
# Packing and unpacking
def details():
    return "Hardeep", 20, "hardeep@gmail.com"

info = details()
name, age, mail = info

print(f"Name: {name}, \nAge: {age}, \nMail: {mail}")
# Out:
# Name: Hardeep,
# Age: 20,
# Mail: hardeep@gmail.com
